# %% [markdown]
# <a href="https://colab.research.google.com/github/dudanobree26/API-de-Dados-com-Planilha/blob/main/API_de_Dados_com_Planilha.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import requests
import json
#para importar data e hora
from datetime import datetime

# %%
#vamos coocar nosso endpoint
url='https://script.google.com/macros/s/AKfycbw7kqNcjcVeNejKVPpDQaNCy_6GnlQb-osCF4S7mRUpVII22Qro3LEg7d4facMdie7z/exec'

#agora vamos criar a função que envia os dados para o excel
def enviar_dados(placa, carro, funcionario):
  #vou colocar a data e hora
  data_e_hora= datetime.now().strftime("%d-%m-%y %H:%M:%S")
  #%d - dia
  #%m - mes
  #%y - ano
  #%H - hora
  #%M - minuto
  #%S - segundos
  #datetima.now() - salva o momento que o codigo foi executado
  parametros={
      'data_e_hora': data_e_hora,
      'placa':placa,
      'carro':modelo,
      'funcionario':funcionario
  }
  print('enviando dados para a tabela')

  resposta= requests.post(url, json=parametros)

  if resposta.status_code == 200:
    print('dados prontos para envio')
  else:
    print(f'erro ao enviar os dados; {resposta.status_code}')

# %%
while True:
  print('-'*50)
  placa = input("inferme a placa do carro: ")
  carro= input('inferme o modelo do carro: ')
  funcionario = input('informe o funcionario que resgistrou: ')

  enviar_dados(placa, carro, funcionario)

  op= input('deseja sair s|n ')
  if op== 's':
    break
